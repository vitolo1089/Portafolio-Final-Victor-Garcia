# %% [markdown]
# <img SRC="CR.jpg"/>
# <center><h1 style="color:#00FFFF"> Analisis de datos </h1></center>
# <center><h4 style="color:#6495ED"> U.Castro Carazo </h4></center>
# <center><h6 style="color:#6495ED"> II Cuatrimestre </h6></center>
# <center><h3 style="color:#FF7A5A"> Victor Garcia Ortiz </h3></center>
# </br>
# </br>
# <p style="font-weight: bold"> La empresa PK2, especialista en venta de vehiculos usados, desea conocer cual es la distribucion y costo de los autos que tienen actualmente en inventario, para la venta.</p>
#
# <p style="font-weight: bold">La pregunta de negocio para responder es: ¿cual es estrategia podria implementar para generar una mayor rotacionde inventario?</p>
#
# <p style="font-weight: bold">El objetivo principal, es poder proponer una estrategia de venta de carros en funcion de los disponibles en el lote actual </p>

# %% [markdown]
# <h2 style="color:#5F9EA0">1. Carga y estandarizacion de los archivos de datos </h2>
# <p style="font-weight: bold"> Que se hace en este apartado?</p>
# <ol>
# <li>Importar las librerias a utilizar </li>
# <li>Importar los set de datos(XLSX, CSV, TXT, SQL, ORACLE) </li>
# <li>Revision de los nombres de las columnas del set de datos </li>
# <li>si tenemos mas de 1 archivo, vamos a unirlos en un unico datafreame </li>

# %% [markdown]
# <h4 style="color:#8A2BE2">1.1 Importar las librerias a utilizar</h4>

# %%
#Se realiza las importaciones de las librerias necesarias para el ejerecicio de analisis de datos, sobre los autos disponibles.

import pandas as pd             #para manejo de los datos -DataFrame-
import numpy as np             #para el manejo de estructuras de datos -Listas_
import matplotlib.pyplot as plt #para la creacion de los graficos

# %% [markdown]
# <h5 style="color:#008B8B">1.2 Importar el Set de datos</h5>
# <h4 style="colo:#5F9EA0"> </h4>La fuente de los datos es la pagina denominada Machine Learning Repository, en esta se puede obtener el nombre de los encabezados del set de datos.

# %%
#Se crea una lista con los nombres de las columnas.
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
"style", "wheels", "engine", "base", "length", "width", "heingt",
"curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
"compression", "horsepower", "peak", "City", "Higway", "price" ]

#Se cargan los set de datos en la memoria de la PC.
df_autos1 = pd.read_csv("autos1.csv", names = cols)
df_autos2 = pd.read_csv("autos2.csv", names = cols)

# %% [markdown]
# <h5 style="color:#8A2BE2">Este Comando me da las dimensiones del set de datos en las filas y columnas</h5>

# %%
df_autos2.shape
# Out:
# (197, 26)

# %%
df_autos1.shape
# Out:
# (97, 26)

# %% [markdown]
# <h4 style="color:#008B8B">1.3 Revision de las columnas</h4>
# <p style="color:#8A2BE2">Este Comando me permite consultar los nombres de las columnas</p>

# %%
df_autos2.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_autos1.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_autos1.head(15)
# Out:
#     symboling normalized    make    fuel aspiration doors      style wheels  \
# 0           0        106  nissan     gas        std  four      sedan    fwd
# 1           0        128  nissan     gas        std  four      sedan    fwd
# 2           0        108  nissan     gas        std  four      wagon    fwd
# 3           0        108  nissan     gas        std  four      sedan    fwd
# 4           3        194  nissan     gas        std   two  hatchback    rwd
# 5           3        194  nissan     gas      turbo   two  hatchback    rwd
# 6           1        231  nissan     gas        std   two  hatchback    rwd
# 7           0        161  peugot     gas        std  four      sedan    rwd
# 8           0        161  peugot  diesel      turbo  four      sedan    rwd
# 9           0          ?  peugot     gas        std  four      wagon    rwd
# 10          0          ?  peugot  diesel      turbo  four      wagon    rwd
# 11          0        161  peugot     gas        std  four      sedan    rwd
# 12          0        161  peugot  diesel      turbo  four      sedan    rwd
# 13          0          ?  peugot     gas        std  four      wagon    rwd
# 14          0          ?  peugot  diesel      turbo  four      wagon    rwd
#
#    engine   base  ...  engine-size  system  bore  stroke compression  \
# 0   front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1   front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2   front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3   front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4   front   91.3  ...          181    mpfi  3.43    3.27         9.0
# 5   front   91.3  ...          181    mpfi  3.43    3.27         7.8
# 6   front   99.2  ...          181    mpfi  3.43    3.27         9.0
# 7   front  107.9  ...          120    mpfi  3.46    3.19         8.4
# 8   front  107.9  ...          152     idi  3.70    3.52        21.0
# 9   front  114.2  ...          120    mpfi  3.46    3.19         8.4
# 10  front  114.2  ...          152     idi  3.70    3.52        21.0
# 11  front  107.9  ...          120    mpfi  3.46    2.19         8.4
# 12  front  107.9  ...          152     idi  3.70    3.52        21.0
# 13  front  114.2  ...          120    mpfi  3.46    2.19         8.4
# 14  front  114.2  ...          152     idi  3.70    3.52        21.0
#
#    horsepower  peak City  Higway  price
# 0          97  5200   27      34   9549
# 1         152  5200   17      22  13499
# 2         152  5200   17      22  14399
# 3         152  5200   19      25  13499
# 4         160  5200   19      25  17199
# 5         200  5200   17      23  19699
# 6         160  5200   19      25  18399
# 7          97  5000   19      24  11900
# 8          95  4150   28      33  13200
# 9          97  5000   19      24  12440
# 10         95  4150   25      25  13860
# 11         95  5000   19      24  15580
# 12         95  4150   28      33  16900
# 13         95  5000   19      24  16695
# 14         95  4150   25      25  17075
#
# [15 rows x 26 columns]

# %% [markdown]
# <h4 style="color:#8A2BE2">Revision y validacion de las variables</h4>
# <p>Este proceso de revision permite identificar varibales o datos que deber ser analizados de manera independiente ya que no concuerdan con el rango de informacion a contener</p>
# </br>
# <p style="color:#8A2BE2"> Se requiere como insumo disponer de los Meta Datos</p>

# %%
df_autos1.tail(10)
# Out:
#     symboling normalized        make    fuel aspiration doors        style  \
# 87          2         94  volkswagen  diesel      turbo  four        sedan
# 88          2         94  volkswagen     gas        std  four        sedan
# 89          3          ?  volkswagen     gas        std   two  convertible
# 90          3        256  volkswagen     gas        std   two    hatchback
# 91          0          ?  volkswagen     gas        std  four        sedan
# 92          0          ?  volkswagen  diesel      turbo  four        sedan
# 93          0          ?  volkswagen     gas        std  four        wagon
# 94         -2        103       volvo     gas        std  four        sedan
# 95         -1         74       volvo     gas        std  four        wagon
# 96         -2        103       volvo     gas        std  four        sedan
#
#    wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 87    fwd  front   97.3  ...           97     idi  3.01    3.40        23.0
# 88    fwd  front   97.3  ...          109    mpfi  3.19    3.40        10.0
# 89    fwd  front   94.5  ...          109    mpfi  3.19    3.40         8.5
# 90    fwd  front   94.5  ...          109    mpfi  3.19    3.40         8.5
# 91    fwd  front  100.4  ...          136    mpfi  3.19    3.40         8.5
# 92    fwd  front  100.4  ...           97     idi  3.01    3.40        23.0
# 93    fwd  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 94    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 95    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 96    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak City  Higway  price
# 87         68  4500   37      42   9495
# 88        100  5500   26      32   9995
# 89         90  5500   24      29  11595
# 90         90  5500   24      29   9980
# 91        110  5500   19      24  13295
# 92         68  4500   33      38  13845
# 93         88  5500   25      31  12290
# 94        114  5400   23      28  12940
# 95        114  5400   23      28  13415
# 96        114  5400   24      28  15985
#
# [10 rows x 26 columns]

# %%
df_autos1.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  97.000000   97.000000   97.000000  97.000000  97.000000    97.000000
# mean    0.855670   98.823711  175.208247  65.872165  54.194845  2587.175258
# std     1.314896    5.332170   10.064062   1.655719   2.416755   412.305914
# min    -2.000000   89.500000  156.900000  63.400000  49.700000  1918.000000
# 25%     0.000000   95.700000  168.900000  64.400000  52.500000  2261.000000
# 50%     0.000000   97.300000  173.500000  65.600000  54.500000  2535.000000
# 75%     2.000000  100.400000  183.500000  66.600000  56.000000  2975.000000
# max     3.000000  114.200000  198.900000  72.300000  59.800000  3485.000000
#
#        engine-size       bore     stroke  compression       City     Higway
# count    97.000000  97.000000  97.000000    97.000000  97.000000  97.000000
# mean    125.432990   3.388969   3.169381    10.570206  25.185567  30.814433
# std      29.560992   0.264412   0.352691     4.373831   5.470241   5.784912
# min      90.000000   2.540000   2.070000     7.000000  17.000000  22.000000
# 25%      98.000000   3.190000   3.030000     9.000000  20.000000  25.000000
# 50%     120.000000   3.430000   3.230000     9.000000  25.000000  30.000000
# 75%     146.000000   3.620000   3.400000     9.400000  28.000000  34.000000
# max     203.000000   3.940000   3.900000    23.000000  38.000000  47.000000

# %%
df_autos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    97 non-null     int64
#  1   normalized   97 non-null     object
#  2   make         97 non-null     object
#  3   fuel         97 non-null     object
#  4   aspiration   97 non-null     object
#  5   doors        97 non-null     object
#  6   style        97 non-null     object
#  7   wheels       97 non-null     object
#  8   engine       97 non-null     object
#  9   base         97 non-null     float64
#  10  length       97 non-null     float64
#  11  width        97 non-null     float64
#  12  heingt       97 non-null     float64
#  13  curb         97 non-null     int64
#  14  engineType   97 non-null     object
#  15  Cylinders    97 non-null     object
#  16  engine-size  97 non-null     int64
#  17  system       97 non-null     object
#  18  bore         97 non-null     float64
#  19  stroke       97 non-null     float64
#  20  compression  97 non-null     float64
#  21  horsepower   97 non-null     object
#  22  peak         97 non-null     object
#  23  City         97 non-null     int64
#  24  Higway       97 non-null     int64
#  25  price        97 non-null     object
# dtypes: float64(7), int64(5), object(14)
# memory usage: 19.8+ KB

# %% [markdown]
# <h4 style="color:#008B8B">1.4 Unir los Set de Datos</h4>

# %%
#df_autos1 - 97 observaciones y 26 columnas
#df_autos2 - 197 observaciones y 26 columnas
unionArchivos = [df_autos1, df_autos2]
df_autos = pd.concat(unionArchivos)
df_autos.shape
# Out:
# (294, 26)

# %% [markdown]
# <h2 style="color:#5F9EA0">2. Manejo de Valores Faltantes </h2>
# <p style="font-weight: bold"> Que se hace en este apartado?</p>
# <ol>
# <li>Identificar como se muestran los valores faltantes y estandarizarlos a NaN </li>
# <li>Contar la cantidad de valores NaN (faltantes) </li>
# <li>Analisis para imputar los valores numericos con la media </li>
# <li>Analisis para imputar los valores caracter con el mas frecuente </li>
# <li>Eliminar filas con valores faltantes </li>
# </ol>
# <h2 style="color:#5F9EA0">2.1 Identificar como se muestran los valores faltantes y estandarizarlos a NaN </h2>

# %%
df_autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0          ?  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4  front   91.3  ...          181    mpfi  3.43    3.27         9.0
# 5  front   91.3  ...          181    mpfi  3.43    3.27         7.8
# 6  front   99.2  ...          181    mpfi  3.43    3.27         9.0
# 7  front  107.9  ...          120    mpfi  3.46    3.19         8.4
# 8  front  107.9  ...          152     idi   3.7    3.52        21.0
# 9  front  114.2  ...          120    mpfi  3.46    3.19         8.4
#
#   horsepower  peak City Higway  price
# 0         97  5200   27     34   9549
# 1        152  5200   17     22  13499
# 2        152  5200   17     22  14399
# 3        152  5200   19     25  13499
# 4        160  5200   19     25  17199
# 5        200  5200   17     23  19699
# 6        160  5200   19     25  18399
# 7         97  5000   19     24  11900
# 8         95  4150   28     33  13200
# 9         97  5000   19     24  12440
#
# [10 rows x 26 columns]

# %% [markdown]
# valores faltantes:NaN (Estandar internacional), "", null, ?, entre otros)

# %%
df_autos.replace("?",np.nan, inplace=True)
df_autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        NaN  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4  front   91.3  ...          181    mpfi  3.43    3.27         9.0
# 5  front   91.3  ...          181    mpfi  3.43    3.27         7.8
# 6  front   99.2  ...          181    mpfi  3.43    3.27         9.0
# 7  front  107.9  ...          120    mpfi  3.46    3.19         8.4
# 8  front  107.9  ...          152     idi   3.7    3.52        21.0
# 9  front  114.2  ...          120    mpfi  3.46    3.19         8.4
#
#   horsepower  peak City Higway  price
# 0         97  5200   27     34   9549
# 1        152  5200   17     22  13499
# 2        152  5200   17     22  14399
# 3        152  5200   19     25  13499
# 4        160  5200   19     25  17199
# 5        200  5200   17     23  19699
# 6        160  5200   19     25  18399
# 7         97  5000   19     24  11900
# 8         95  4150   28     33  13200
# 9         97  5000   19     24  12440
#
# [10 rows x 26 columns]

# %% [markdown]
# <h2 style="color:#5F9EA0">2.2 Contar la cantidad de valores NaN (faltantes)</h2>

# %%
valoresperdidos = df_autos.isnull()
valoresperdidos.head(10)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False       False  False  False       False  False  False   False
# 1      False       False  False  False       False  False  False   False
# 2      False       False  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
# 5      False       False  False  False       False  False  False   False
# 6      False       False  False  False       False  False  False   False
# 7      False       False  False  False       False  False  False   False
# 8      False       False  False  False       False  False  False   False
# 9      False        True  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# 1   False  False  ...        False   False  False   False        False
# 2   False  False  ...        False   False  False   False        False
# 3   False  False  ...        False   False  False   False        False
# 4   False  False  ...        False   False  False   False        False
# 5   False  False  ...        False   False  False   False        False
# 6   False  False  ...        False   False  False   False        False
# 7   False  False  ...        False   False  False   False        False
# 8   False  False  ...        False   False  False   False        False
# 9   False  False  ...        False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# 1       False  False  False   False  False
# 2       False  False  False   False  False
# 3       False  False  False   False  False
# 4       False  False  False   False  False
# 5       False  False  False   False  False
# 6       False  False  False   False  False
# 7       False  False  False   False  False
# 8       False  False  False   False  False
# 9       False  False  False   False  False
#
# [10 rows x 26 columns]

# %%
for column in valoresperdidos.columns.values.tolist():
    print(column)
    print(valoresperdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    237
# True      57
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    292
# True       2
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# False    294
# Name: system, dtype: int64
#
# bore
# False    290
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    290
# True       4
# Name: stroke, dtype: int64
#
# compression
# False    294
# Name: compression, dtype: int64
#
# horsepower
# False    290
# True       4
# Name: horsepower, dtype: int64
#
# peak
# False    290
# True       4
# Name: peak, dtype: int64
#
# City
# False    294
# Name: City, dtype: int64
#
# Higway
# False    294
# Name: Higway, dtype: int64
#
# price
# False    289
# True       5
# Name: price, dtype: int64

# %% [markdown]
# <h2 style="color:#5F9EA0">2.3 Analisis para imputar los valores numericos con la media</h2>

# %%
avg_norm = df_autos["normalized"].astype("float").mean(axis=0)
print ("LA media  es:", avg_norm)
# Out:
# LA media  es: 122.26160337552743

# %%
df_autos["normalized"].replace(np.NaN, 122, inplace=True) 
df_autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        122  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4  front   91.3  ...          181    mpfi  3.43    3.27         9.0
# 5  front   91.3  ...          181    mpfi  3.43    3.27         7.8
# 6  front   99.2  ...          181    mpfi  3.43    3.27         9.0
# 7  front  107.9  ...          120    mpfi  3.46    3.19         8.4
# 8  front  107.9  ...          152     idi   3.7    3.52        21.0
# 9  front  114.2  ...          120    mpfi  3.46    3.19         8.4
#
#   horsepower  peak City Higway  price
# 0         97  5200   27     34   9549
# 1        152  5200   17     22  13499
# 2        152  5200   17     22  14399
# 3        152  5200   19     25  13499
# 4        160  5200   19     25  17199
# 5        200  5200   17     23  19699
# 6        160  5200   19     25  18399
# 7         97  5000   19     24  11900
# 8         95  4150   28     33  13200
# 9         97  5000   19     24  12440
#
# [10 rows x 26 columns]

# %% [markdown]
# <h2 style="color:#5F9EA0">2.4 Analisis para imputar los valores caracter con el mas frecuente</h2>

# %%
df_autos["doors"].value_counts() #contar valores
# Out:
# four    167
# two     125
# Name: doors, dtype: int64

# %%
df_autos["doors"].value_counts().idxmax() #Valor mas frecuente
# Out:
# 'four'

# %%
df_autos["doors"].replace(np.nan, "four", inplace=True)

# %%
valoresperdidos = df_autos.isnull()
for column in valoresperdidos.columns.values.tolist():
    print(column)
    print(valoresperdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    294
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    294
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# False    294
# Name: system, dtype: int64
#
# bore
# False    290
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    290
# True       4
# Name: stroke, dtype: int64
#
# compression
# False    294
# Name: compression, dtype: int64
#
# horsepower
# False    290
# True       4
# Name: horsepower, dtype: int64
#
# peak
# False    290
# True       4
# Name: peak, dtype: int64
#
# City
# False    294
# Name: City, dtype: int64
#
# Higway
# False    294
# Name: Higway, dtype: int64
#
# price
# False    289
# True       5
# Name: price, dtype: int64

# %% [markdown]
# <h2 style="color:#5F9EA0">2.5 Eliminar filas con valores faltantes</h2>

# %%
df_autos.dropna(subset = ("price"), axis=0, inplace=True) 
df_autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 192          0        122  volkswagen  diesel      turbo  four      sedan
# 193          0        122  volkswagen     gas        std  four      wagon
# 194         -2        103       volvo     gas        std  four      sedan
# 195         -1         74       volvo     gas        std  four      wagon
# 196         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0      fwd  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1      fwd  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2      fwd  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3      fwd  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4      rwd  front   91.3  ...          181    mpfi  3.43    3.27         9.0
# ..     ...    ...    ...  ...          ...     ...   ...     ...         ...
# 192    fwd  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193    fwd  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 0           97  5200   27     34   9549
# 1          152  5200   17     22  13499
# 2          152  5200   17     22  14399
# 3          152  5200   19     25  13499
# 4          160  5200   19     25  17199
# ..         ...   ...  ...    ...    ...
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [289 rows x 26 columns]

# %%
df_autos.reset_index(drop=True, inplace=True) #reiniiciar indice
df_autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 284          0        122  volkswagen  diesel      turbo  four      sedan
# 285          0        122  volkswagen     gas        std  four      wagon
# 286         -2        103       volvo     gas        std  four      sedan
# 287         -1         74       volvo     gas        std  four      wagon
# 288         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0      fwd  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1      fwd  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2      fwd  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3      fwd  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4      rwd  front   91.3  ...          181    mpfi  3.43    3.27         9.0
# ..     ...    ...    ...  ...          ...     ...   ...     ...         ...
# 284    fwd  front  100.4  ...           97     idi  3.01    3.40        23.0
# 285    fwd  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 286    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 287    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 288    rwd  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 0           97  5200   27     34   9549
# 1          152  5200   17     22  13499
# 2          152  5200   17     22  14399
# 3          152  5200   19     25  13499
# 4          160  5200   19     25  17199
# ..         ...   ...  ...    ...    ...
# 284         68  4500   33     38  13845
# 285         88  5500   25     31  12290
# 286        114  5400   23     28  12940
# 287        114  5400   23     28  13415
# 288        114  5400   24     28  15985
#
# [289 rows x 26 columns]

# %% [markdown]
# <h2 style="color:#5F9EA0"> 3 Estanadarizacion de los datos</h2>
#     Que se hace en este apartado?
# <ol>
# <li>Se verifica el dominio del la variabley se ajusta, si es necesario </li>
# <li>Se corvienten los valores en funcion de su interpretracion. </li>
# <li>Se normalizan los datos para que los valores distintos queden entre 0 y 1 </li>
# <li>Binning </li>

# %% [markdown]
# <h2 style="color:#8A2BE2">3.1 Verificacion del dominio de variable</h2>

# %%
df_autos.head(5)
# Out:
#    symboling normalized    make fuel aspiration doors      style wheels  \
# 0          0        106  nissan  gas        std  four      sedan    fwd
# 1          0        128  nissan  gas        std  four      sedan    fwd
# 2          0        108  nissan  gas        std  four      wagon    fwd
# 3          0        108  nissan  gas        std  four      sedan    fwd
# 4          3        194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# 1  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 2  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 3  front  100.4  ...          181    mpfi  3.43    3.27         9.0
# 4  front   91.3  ...          181    mpfi  3.43    3.27         9.0
#
#   horsepower  peak City Higway  price
# 0         97  5200   27     34   9549
# 1        152  5200   17     22  13499
# 2        152  5200   17     22  14399
# 3        152  5200   19     25  13499
# 4        160  5200   19     25  17199
#
# [5 rows x 26 columns]

# %%
df_autos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
##Esto se realiza para estandarizar los tipos de datos del negocio, no es necesario hacerlo siempre, es por el ejemplo didactico
df_autos.dropna(subset = ("horsepower"), axis=0, inplace=True)
df_autos.dropna(subset = ("normalized"), axis=0, inplace=True)
df_autos.reset_index(drop=True, inplace=True)

##--------------------------------------------------------------------
df_autos[['bore','stroke','peak']] = df_autos[['bore','stroke','peak']].astype('float')
df_autos[['price']] = df_autos[['price']] .astype('float')
df_autos[['normalized']] = df_autos[['normalized']] .astype('int')
df_autos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower      object
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h2 style="color:#5F9EA0"> 3.2 Estandarizar valor</h2>

# %%
df_autos.head(3)
# Out:
#    symboling  normalized    make fuel aspiration doors  style wheels engine  \
# 0          0         106  nissan  gas        std  four  sedan    fwd  front
# 1          0         128  nissan  gas        std  four  sedan    fwd  front
# 2          0         108  nissan  gas        std  four  wagon    fwd  front
#
#     base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0   97.2  ...          120    2bbl  3.33    3.47         8.5         97
# 1  100.4  ...          181    mpfi  3.43    3.27         9.0        152
# 2  100.4  ...          181    mpfi  3.43    3.27         9.0        152
#
#      peak City  Higway    price
# 0  5200.0   27      34   9549.0
# 1  5200.0   17      22  13499.0
# 2  5200.0   17      22  14399.0
#
# [3 rows x 26 columns]

# %%
df_autos["City-L/100km"] = 235/df_autos["City"]
df_autos["Higway-L/100km"] = 235/df_autos["Higway"]
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  bore  stroke  compression  horsepower    peak City  \
# 0  front   97.2  ...  3.33    3.47          8.5          97  5200.0   27
# 1  front  100.4  ...  3.43    3.27          9.0         152  5200.0   17
# 2  front  100.4  ...  3.43    3.27          9.0         152  5200.0   17
# 3  front  100.4  ...  3.43    3.27          9.0         152  5200.0   19
# 4  front   91.3  ...  3.43    3.27          9.0         160  5200.0   19
#
#    Higway    price  City-L/100km  Higway-L/100km
# 0      34   9549.0      8.703704        6.911765
# 1      22  13499.0     13.823529       10.681818
# 2      22  14399.0     13.823529       10.681818
# 3      25  13499.0     12.368421        9.400000
# 4      25  17199.0     12.368421        9.400000
#
# [5 rows x 28 columns]

# %% [markdown]
# <h2 style="color:#5F9EA0"> 3.3 Normalizar Valores </h2>

# %%
##Esto se hace para poder volver comparable los datos y poder normalizar los valores para efecto de una grafica
df_autos["length"] = df_autos['length']/df_autos['length'].max()
df_autos["width"] = df_autos['width']/df_autos['width'].max()
df_autos["heingt"] = df_autos['heingt']/df_autos['heingt'].max()

# %%
dfTemp = df_autos[["length", "width", "heingt" ]]
dfTemp
# Out:
#        length     width    heingt
# 0    0.833253  0.905556  0.914716
# 1    0.873138  0.923611  0.921405
# 2    0.887074  0.923611  0.938127
# 3    0.887074  0.923611  0.921405
# 4    0.820279  0.943056  0.831104
# ..        ...       ...       ...
# 280  0.865930  0.929167  0.921405
# 281  0.879865  0.929167  0.921405
# 282  0.907256  0.933333  0.939799
# 283  0.907256  0.933333  0.961538
# 284  0.907256  0.933333  0.939799
#
# [285 rows x 3 columns]

# %% [markdown]
# <h2 style="color:#5F9EA0"> 3.4 Binning </h2>

# %%
df_autos
# Out:
#      symboling  normalized        make    fuel aspiration doors      style  \
# 0            0         106      nissan     gas        std  four      sedan
# 1            0         128      nissan     gas        std  four      sedan
# 2            0         108      nissan     gas        std  four      wagon
# 3            0         108      nissan     gas        std  four      sedan
# 4            3         194      nissan     gas        std   two  hatchback
# ..         ...         ...         ...     ...        ...   ...        ...
# 280          0         122  volkswagen  diesel      turbo  four      sedan
# 281          0         122  volkswagen     gas        std  four      wagon
# 282         -2         103       volvo     gas        std  four      sedan
# 283         -1          74       volvo     gas        std  four      wagon
# 284         -2         103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  bore  stroke  compression  horsepower    peak  \
# 0      fwd  front   97.2  ...  3.33    3.47          8.5          97  5200.0
# 1      fwd  front  100.4  ...  3.43    3.27          9.0         152  5200.0
# 2      fwd  front  100.4  ...  3.43    3.27          9.0         152  5200.0
# 3      fwd  front  100.4  ...  3.43    3.27          9.0         152  5200.0
# 4      rwd  front   91.3  ...  3.43    3.27          9.0         160  5200.0
# ..     ...    ...    ...  ...   ...     ...          ...         ...     ...
# 280    fwd  front  100.4  ...  3.01    3.40         23.0          68  4500.0
# 281    fwd  front  100.4  ...  3.19    3.40          9.0          88  5500.0
# 282    rwd  front  104.3  ...  3.78    3.15          9.5         114  5400.0
# 283    rwd  front  104.3  ...  3.78    3.15          9.5         114  5400.0
# 284    rwd  front  104.3  ...  3.78    3.15          9.5         114  5400.0
#
#     City  Higway    price  City-L/100km  Higway-L/100km
# 0     27      34   9549.0      8.703704        6.911765
# 1     17      22  13499.0     13.823529       10.681818
# 2     17      22  14399.0     13.823529       10.681818
# 3     19      25  13499.0     12.368421        9.400000
# 4     19      25  17199.0     12.368421        9.400000
# ..   ...     ...      ...           ...             ...
# 280   33      38  13845.0      7.121212        6.184211
# 281   25      31  12290.0      9.400000        7.580645
# 282   23      28  12940.0     10.217391        8.392857
# 283   23      28  13415.0     10.217391        8.392857
# 284   24      28  15985.0      9.791667        8.392857
#
# [285 rows x 28 columns]

# %%
df_autos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engine-size         int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower         object
# peak              float64
# City                int64
# Higway              int64
# price             float64
# City-L/100km      float64
# Higway-L/100km    float64
# dtype: object

# %%
df_autos[['horsepower']] = df_autos[['horsepower']] .astype('int')

# %%
df_autos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engine-size         int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower          int32
# peak              float64
# City                int64
# Higway              int64
# price             float64
# City-L/100km      float64
# Higway-L/100km    float64
# dtype: object

# %%
bins = np.linspace(min(df_autos["horsepower"]), max(df_autos["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
nombre = ["pequeño", "mediano", "grande"]
df_autos["horsepower-bins"] = pd.cut(df_autos["horsepower"], bins, labels=nombre, include_lowest=True)
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price City-L/100km  Higway-L/100km  horsepower-bins
# 0   9549.0     8.703704        6.911765          pequeño
# 1  13499.0    13.823529       10.681818          mediano
# 2  14399.0    13.823529       10.681818          mediano
# 3  13499.0    12.368421        9.400000          mediano
# 4  17199.0    12.368421        9.400000          mediano
#
# [5 rows x 29 columns]

# %%
df_autos[["horsepower", "horsepower-bins"]].head(10)
# Out:
#    horsepower horsepower-bins
# 0          97         pequeño
# 1         152         mediano
# 2         152         mediano
# 3         152         mediano
# 4         160         mediano
# 5         200          grande
# 6         160         mediano
# 7          97         pequeño
# 8          95         pequeño
# 9          97         pequeño

# %%
df_autos[["horsepower", "horsepower-bins"]].value_counts()
# Out:
# horsepower  horsepower-bins
# 68          pequeño            25
# 70          pequeño            16
# 116         pequeño            15
# 95          pequeño            14
# 110         pequeño            13
# 62          pequeño            12
# 69          pequeño            11
# 82          pequeño            10
# 97          pequeño             9
# 92          pequeño             8
# 160         mediano             8
# 88          pequeño             8
# 85          pequeño             6
# 111         pequeño             6
# 101         pequeño             6
# 114         pequeño             6
# 145         mediano             6
# 102         pequeño             6
# 152         mediano             6
# 207         grande              6
# 73          pequeño             6
# 84          pequeño             5
# 90          pequeño             5
# 76          pequeño             5
# 156         mediano             4
# 123         mediano             4
# 56          pequeño             4
# 161         mediano             4
# 86          pequeño             4
# 52          pequeño             4
# 94          pequeño             4
# 112         pequeño             4
# 182         mediano             3
# 100         pequeño             3
# 121         mediano             3
# 176         mediano             2
# 184         mediano             2
# 200         grande              2
# 155         mediano             2
# 142         mediano             2
# 143         mediano             2
# 175         mediano             1
# 154         mediano             1
# 48          pequeño             1
# 140         mediano             1
# 135         mediano             1
# 120         mediano             1
# 115         pequeño             1
# 78          pequeño             1
# 72          pequeño             1
# 64          pequeño             1
# 60          pequeño             1
# 58          pequeño             1
# 55          pequeño             1
# 262         grande              1
# dtype: int64

# %%
df_autos[["horsepower-bins"]].value_counts()
# Out:
# horsepower-bins
# pequeño            223
# mediano             53
# grande               9
# dtype: int64

# %%
df_autos.shape
# Out:
# (285, 29)

# %%
##histograma
plt.hist(df_autos["horsepower-bins"])
plt.xlabel("Categorias")
plt.ylabel("Cantidad de Autos")
plt.title("Cantidad de Autos segun Caballos de Fuerza")
plt.show()

# %% [markdown]
# <h2 style="color:#5F9EA0"> 4 Vizualizacion de los datos</h2>
# En este apartado se van a crear diferentes visualizaciones (Graficas) , las cuales nos ayudan a realizar la interpretacion y analisis de la informacion del set
# <ol>
# <p> Estos son tres elementos fundamentales para poder crear las visualizaciones: </p>
# <li>Pregunta de negocio a responder. </li>
# <li>Pleno conocimiento del set de datos </li>
# <li>Experiencia de negocio</li>

# %% [markdown]
# <h3 style="color:#8A2BE2"> Grafico Barras </h3>

# %%
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price City-L/100km  Higway-L/100km  horsepower-bins
# 0   9549.0     8.703704        6.911765          pequeño
# 1  13499.0    13.823529       10.681818          mediano
# 2  14399.0    13.823529       10.681818          mediano
# 3  13499.0    12.368421        9.400000          mediano
# 4  17199.0    12.368421        9.400000          mediano
#
# [5 rows x 29 columns]

# %%
#Agrupar las observaciones segun marca de vehiculo
gf1 = df_autos.groupby(['make']).count()
gfi = gf1.iloc[:,:1]
gf1 = df_autos.rename(columns={'make':'marca', 'symboling':'cantidad'})
gf1
# Out:
#      cantidad  normalized       marca    fuel aspiration doors      style  \
# 0           0         106      nissan     gas        std  four      sedan
# 1           0         128      nissan     gas        std  four      sedan
# 2           0         108      nissan     gas        std  four      wagon
# 3           0         108      nissan     gas        std  four      sedan
# 4           3         194      nissan     gas        std   two  hatchback
# ..        ...         ...         ...     ...        ...   ...        ...
# 280         0         122  volkswagen  diesel      turbo  four      sedan
# 281         0         122  volkswagen     gas        std  four      wagon
# 282        -2         103       volvo     gas        std  four      sedan
# 283        -1          74       volvo     gas        std  four      wagon
# 284        -2         103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  stroke  compression  horsepower    peak City  \
# 0      fwd  front   97.2  ...    3.47          8.5          97  5200.0   27
# 1      fwd  front  100.4  ...    3.27          9.0         152  5200.0   17
# 2      fwd  front  100.4  ...    3.27          9.0         152  5200.0   17
# 3      fwd  front  100.4  ...    3.27          9.0         152  5200.0   19
# 4      rwd  front   91.3  ...    3.27          9.0         160  5200.0   19
# ..     ...    ...    ...  ...     ...          ...         ...     ...  ...
# 280    fwd  front  100.4  ...    3.40         23.0          68  4500.0   33
# 281    fwd  front  100.4  ...    3.40          9.0          88  5500.0   25
# 282    rwd  front  104.3  ...    3.15          9.5         114  5400.0   23
# 283    rwd  front  104.3  ...    3.15          9.5         114  5400.0   23
# 284    rwd  front  104.3  ...    3.15          9.5         114  5400.0   24
#
#     Higway    price City-L/100km  Higway-L/100km  horsepower-bins
# 0       34   9549.0     8.703704        6.911765          pequeño
# 1       22  13499.0    13.823529       10.681818          mediano
# 2       22  14399.0    13.823529       10.681818          mediano
# 3       25  13499.0    12.368421        9.400000          mediano
# 4       25  17199.0    12.368421        9.400000          mediano
# ..     ...      ...          ...             ...              ...
# 280     38  13845.0     7.121212        6.184211          pequeño
# 281     31  12290.0     9.400000        7.580645          pequeño
# 282     28  12940.0    10.217391        8.392857          pequeño
# 283     28  13415.0    10.217391        8.392857          pequeño
# 284     28  15985.0     9.791667        8.392857          pequeño
#
# [285 rows x 29 columns]

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf1 = df_autos.groupby(['make']).count()
gf1 = gf1.iloc[:,:1]
gf1
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   6
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  2
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                25
# peugot                22
# plymouth              14
# porsche                8
# saab                  12
# subaru                24
# toyota                64
# volkswagen            24
# volvo                  6

# %%
marcas = ("alfa-romero", "audi", "bmw","chevrolet", "dodge", "honda", "isuzu", "jaguar", "mazda", "Merecedez", "Mercury",
        "mitsubishi", "nissan", "peugot", "plymounth", "porshe", "saab", "subaru", "toyota", "volkswagen", "volvo")

eje_y = gf1['symboling'].tolist()

plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(len(marcas))

ax.barh(y_pos, eje_y, align='center',height=0.8, color= "#006400", alpha=1)

ax.set_yticks(y_pos, labels=marcas)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Cantidad de Vehiculos').set_color("#006400")
ax.set_title('¿Cual es la marca con mayor representación en el invetario?')

plt.show()

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf2 = df_autos.groupby(['horsepower-bins']).count()
gf2 = gf2.iloc[:,:1]
gf2
# Out:
#                  symboling
# horsepower-bins
# pequeño                223
# mediano                 53
# grande                   9

# %%
marcas = ("Pequeno", "Mediano","Grande")

eje_y = gf2['symboling'].tolist()

#Creamos la grafica
plt.bar(marcas, eje_y)

#Leyenda del eje y
plt.ylabel("Cantidad de Vehiculos")

##Leyenda en el eje x
plt.xlabel("Marca de Vehiculos")

##Titulo del Grafico
plt.title('¿Cantidad de autos segun caballos de fuerza?')

plt.show()

# %%
#Agrupar los carros segun estilo.
gf3 = df_autos.groupby(['style']).count()
gf3 = gf3.iloc[:,:1]
gf3
# Out:
#              symboling
# style
# convertible          9
# hardtop             13
# hatchback           96
# sedan              129
# wagon               38

# %%
style = ("convertible", "hardtop","hatchback","sedan","wagon")

eje_y = gf3['symboling'].tolist()

#Creamos la grafica
plt.bar(style, eje_y)

#Leyenda del eje y
plt.ylabel("Cantidad de Vehiculos")

##Leyenda en el eje x
plt.xlabel("Tipo Estilo de Vehiculos")

##Titulo del Grafico
plt.title('¿Cantidad de vehiculos segun estilo?')

plt.show()

# %%
#Agrupar las observaciones segun marca de vehiculo.
gf3 = df_autos.groupby(['style']).count()
gf3 = gf3.iloc[:,:1]

#Codigo para ordenar los valores ascendente y desendente
gf3 = gf3.sort_values('symboling') #Ordena de Menor a Mayor
#gf3 = gf3.sort_values('symboling',ascending=False) #Ordena de Mayor a Menor
gf3
# Out:
#              symboling
# style
# convertible          9
# hardtop             13
# wagon               38
# hatchback           96
# sedan              129

# %%
#Codigo para obtener la lista del indice del DataFrame
eje_x = gf3.index.tolist()

eje_y = gf3['symboling'].tolist()

#Creamos la grafica
plt.bar(eje_x, eje_y)

#Leyenda del eje y
plt.ylabel("Cantidad de Vehiculos")

##Leyenda en el eje x
plt.xlabel("estilo de Vehiculos")

##Titulo del Grafico
plt.title('Cantidad de autos segun estilo')

plt.show()

# %% [markdown]
# <h3 style="color:#8A2BE2"> Grafico Circular </h3>

# %%
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price City-L/100km  Higway-L/100km  horsepower-bins
# 0   9549.0     8.703704        6.911765          pequeño
# 1  13499.0    13.823529       10.681818          mediano
# 2  14399.0    13.823529       10.681818          mediano
# 3  13499.0    12.368421        9.400000          mediano
# 4  17199.0    12.368421        9.400000          mediano
#
# [5 rows x 29 columns]

# %%
gf4 = df_autos.groupby(['doors']).count()
gf4 = gf4.iloc[:,:1]
gf4
# Out:
#        symboling
# doors
# four         166
# two          119

# %%
#Grafico Circulas
etiquetas = gf4.index.tolist()
sizes = gf4["symboling"].tolist()

separacion = (0, 0.1)

figl, axl = plt.subplots()
axl.pie(sizes, explode=separacion, labels=etiquetas, autopct='%1.1f%%',shadow=True, startangle=90)
axl.axis('equal')
plt.show()

# %%
gf5 = df_autos.groupby(['style']).count()
gf5 = gf5.iloc[:,:1]
gf5
# Out:
#              symboling
# style
# convertible          9
# hardtop             13
# hatchback           96
# sedan              129
# wagon               38

# %%
fig, ax = plt.subplots(figsize=(9, 3), subplot_kw=dict(aspect="equal"))
 
data = gf5['symboling'].tolist()
estilo = gf5.index.tolist()
 
def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%".format(pct, absolute)
 

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))
 
ax.legend(wedges, estilo,
          title="Estilos",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
 
plt.setp(autotexts, size=5, weight="bold")
 
ax.set_title("Porcentaje de vehiculos segun estilo")
 
plt.show()

# %%
# Colores del grafico: FFB85F FF7A5A 00AAA0 8ED2C9 FCF4D9
colores = ['#FFB85F', '#FF7A5A', '#00AAA0', '#8ED2C9', '#FCF4D9']
#Separaciones
separacion = (0.07,0.07,0.07,0.07,0.07)
#Creacion graficca circular
plt.pie(data, explode=separacion, labels=estilo, autopct='%1.1f%%',pctdistance=0.85, colors=colores)
 
#Dibujar Circulo Blanco
circulo = plt.Circle((0,0), 0.75, fc='white')
fig = plt.gcf()
fig.gca().add_artist(circulo)
 
plt.title("Porcentaje de vehiculos segun estilo")
 
plt.show()

# %% [markdown]
# <h3 style="color:#8A2BE2"> Grafico Dispersion </h3>

# %%
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price City-L/100km  Higway-L/100km  horsepower-bins
# 0   9549.0     8.703704        6.911765          pequeño
# 1  13499.0    13.823529       10.681818          mediano
# 2  14399.0    13.823529       10.681818          mediano
# 3  13499.0    12.368421        9.400000          mediano
# 4  17199.0    12.368421        9.400000          mediano
#
# [5 rows x 29 columns]

# %%
import matplotlib.cbook as cbook
 
fig, ax = plt.subplots()
ax.scatter(df_autos['price'], df_autos['City-L/100km'],s=df_autos['horsepower'], alpha=0.5)
#ax.scatter(df_Autos['price'], df_Autos['horsepower-bins'],alpha=0.5)
ax.set_xlabel("Precio", fontsize=15)
ax.set_ylabel("Consumo Combustible en Ciudad", fontsize=15)
ax.set_title('Correlacion Precio vrs Consumo de Combustible en Ciudad')
 
ax.grid(True)
fig.tight_layout()
 
plt.show()
